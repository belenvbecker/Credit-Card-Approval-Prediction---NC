# %%
import pandas as pd


df = pd.read_csv('application_record.csv')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
#Verificación de datos nulos. Solamente hay 134.203 datos nulos en la columna OCCUPATION_TYPE 

df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
#Verificación de valores únicos en la columna OCCUPATION_TYPE

df['OCCUPATION_TYPE'].unique()
# Out:
# array([nan, 'Security staff', 'Sales staff', 'Accountants', 'Laborers',
#        'Managers', 'Drivers', 'Core staff', 'High skill tech staff',
#        'Cleaning staff', 'Private service staff', 'Cooking staff',
#        'Low-skill Laborers', 'Medicine staff', 'Secretaries',
#        'Waiters/barmen staff', 'HR staff', 'Realty agents', 'IT staff'],
#       dtype=object)

# %%
#Verificación de datos duplicados. No hay

cantidad_duplicados = df.duplicated().sum()
cantidad_duplicados
# Out:
# 0

# %%
#Reemplazar en la columna FLAG_OWN_CAR los valores Y por 1 y N por 0

df['FLAG_OWN_CAR'] = df['FLAG_OWN_CAR'].replace({'N': 0, 'Y': 1})

# %%
df
# Out:
#              ID CODE_GENDER  FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M             1               Y             0
# 1       5008805           M             1               Y             0
# 2       5008806           M             1               Y             0
# 3       5008808           F             0               Y             0
# 4       5008809           F             0               Y             0
# ...         ...         ...           ...             ...           ...
# 438552  6840104           M             0               Y             0
# 438553  6840222           F             0               N             0
# 438554  6841878           F             0               N             0
# 438555  6842765           F             0               Y             0
# 438556  6842885           F             0               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
#Reemplazar en la columna FLAG_OWN_REALTY los valores Y por 1 y N por 0

df['FLAG_OWN_REALTY'] = df['FLAG_OWN_REALTY'].replace({'N': 0, 'Y': 1})

# %%
df
# Out:
#              ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M             1                1             0
# 1       5008805           M             1                1             0
# 2       5008806           M             1                1             0
# 3       5008808           F             0                1             0
# 4       5008809           F             0                1             0
# ...         ...         ...           ...              ...           ...
# 438552  6840104           M             0                1             0
# 438553  6840222           F             0                0             0
# 438554  6841878           F             0                0             0
# 438555  6842765           F             0                1             0
# 438556  6842885           F             0                1             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
#Pasar a fecha la columna DAYS_BIRTH

df['fecha_nacimiento'] = pd.to_datetime('2024-01-01') + pd.to_timedelta(df['DAYS_BIRTH'], unit='D')

# %%
df['fecha_nacimiento']
# Out:
# 0        1991-02-18
# 1        1991-02-18
# 2        1965-03-17
# 3        1971-09-06
# 4        1971-09-06
#             ...
# 438552   1961-10-21
# 438553   1980-05-12
# 438554   2001-08-20
# 438555   1964-08-30
# 438556   1972-05-15
# Name: fecha_nacimiento, Length: 438557, dtype: datetime64[ns]

# %%
df
# Out:
#              ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M             1                1             0
# 1       5008805           M             1                1             0
# 2       5008806           M             1                1             0
# 3       5008808           F             0                1             0
# 4       5008809           F             0                1             0
# ...         ...         ...           ...              ...           ...
# 438552  6840104           M             0                1             0
# 438553  6840222           F             0                0             0
# 438554  6841878           F             0                0             0
# 438555  6842765           F             0                1             0
# 438556  6842885           F             0                1             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
#Eliminar la columna DAYS_BIRTH

df.drop(columns=['DAYS_BIRTH'], inplace=True)

# %%
df.loc[df['NAME_INCOME_TYPE'] == 'Pensioner']
# Out:
#              ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 7       5008812           F             0                1             0
# 8       5008813           F             0                1             0
# 9       5008814           F             0                1             0
# 76      5008884           F             0                1             0
# 160     5008974           F             0                1             0
# ...         ...         ...           ...              ...           ...
# 438549  6840098           F             0                1             0
# 438550  6840100           F             0                1             0
# 438551  6840102           F             0                1             0
# 438552  6840104           M             0                1             0
# 438555  6842765           F             0                1             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...
